# %% [markdown]
# # Feasibility pipeline launcher
#
# Three cells: clone, install, run. Enable a GPU (P100 or T4 x2) in
# *Settings → Accelerator* before running. Use *Save & Run All (Commit)*
# for background execution.

# %%
import os
if os.path.exists('nlp-project'):
    # !cd nlp-project && git pull
else:
    # !git clone https://github.com/hadasy-tau/nlp-project.git

# %%
# !pip install -q -r nlp-project/requirements.txt

# %%
# !cd nlp-project && python run_pipeline.py --config configs/kaggle.yaml
