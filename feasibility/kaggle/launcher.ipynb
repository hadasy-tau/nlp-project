# %% [markdown]
# # Feasibility pipeline launcher
#
# Three cells: clone, install, run. Enable a GPU (P100 or T4 x2) in
# *Settings → Accelerator* before running. Use *Save & Run All (Commit)*
# for background execution.

# %%
# REF can be a branch, or a commit SHA to pin a run exactly.
REF = 'main'   # the feasibility pipeline lives in feasibility/ on main

import os
if os.path.exists('nlp-project'):
    # !cd nlp-project && git fetch && git checkout {REF} && git pull --ff-only || true
else:
    # !git clone https://github.com/hadasy-tau/nlp-project.git && cd nlp-project && git checkout {REF}

# %%
# !pip install -q -r nlp-project/feasibility/requirements.txt

# %%
# !cd nlp-project/feasibility && python run_pipeline.py --config configs/kaggle.yaml
